# %% [markdown]
# # Prédicteur de Charges d'Assurance Maladie (partie 1) :

# %% [markdown]
# ## ➕ Feature Story 1 : Analyse et Préparation des Données

# %% [markdown]
# ### ▶️ Tâche 1 : Chargement des données

# %% [markdown]
# * Installer les packages :

# %%
# !pip install numpy matplotlib pandas
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: pandas in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ramas\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ramas\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# * Les imports :

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sbs
import matplotlib.pyplot as plt

# %% [markdown]
# * Importer Datasets :

# %%
data_frame = pd.read_csv("assurance-maladie-68d92978e362f464596651.csv")
print("data : \n", data_frame)
# Out:
# data :
#        age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# * nombre des lignes , nombre des colonnes :

# %%
print("(nombre des lignes , nombre des colonnes) = ", data_frame.shape)
# Out:
# (nombre des lignes , nombre des colonnes) =  (1338, 7)

# %% [markdown]
# * Types des données :

# %%
print("Types des données : \n", data_frame.dtypes)
# Out:
# Types des données :
#  age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# * Les nomsdes colonnes :

# %%
print("Les colonnes : \n", data_frame.columns)
# Out:
# Les colonnes :
#  Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# * Les première lignes :

# %%
print("Les première lignes : \n", data_frame.head())
# Out:
# Les première lignes :
#     age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# * Le nombre des hommes des femmes :

# %%
print("Le nombre des hommes des femmes : ")
data_frame['sex'].value_counts()
# Out:
# Le nombre des hommes des femmes :
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# ### ▶️ Tâche 2 : Analyse exploratoire des données (EDA)

# %% [markdown]
# * Types des données :

# %%
print("Types des données : ", data_frame.dtypes)
# Out:
# Types des données :  age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# * Statistiques descriptives (numériques) :

# %%
print("Statistiques descriptives (numériques) :\n", data_frame.describe(include=['number']))
# Out:
# Statistiques descriptives (numériques) :
#                 age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# * Statistiques descriptives (catégoriques) :

# %%
print("Statistiques descriptives (catégoriques) :\n", data_frame.describe(include=['object']))
# Out:
# Statistiques descriptives (catégoriques) :
#           sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# * Statistiques descriptives (all) :

# %%
print("Statistiques descriptives (all) :\n", pd.DataFrame(data_frame.describe(include='all')))
# Out:
# Statistiques descriptives (all) :
#                  age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    13270.422265
# std     12110.011237
# min      1121.873900
# 25%      4740.287150
# 50%      9382.033000
# 75%     16639.912515
# max     63770.428010

# %% [markdown]
# * Valeurs uniques par colonne :

# %%
print("\nValeurs uniques par colonne :\n", data_frame.nunique())
# Out:
# Valeurs uniques par colonne :
#  age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %% [markdown]
# * Les valeurs manquantes :

# %%
print("Identifier les valeurs manquantes par colonne : ")
data_frame.isnull().sum()
# Out:
# Identifier les valeurs manquantes par colonne :
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# * Identifier les doublons.

# %%
print("Identifier lesvaleurs  doublons: ", data_frame.duplicated().sum())
# Out:
# Identifier lesvaleurs  doublons:  1

# %% [markdown]
# * Analyser la distribution des variables numériques (ex. : histogrammes avec Matplotlib/Seaborn):

# %%
data_frame.hist(bins=50, figsize=(12, 8))
plt.title('Distribution des variables numériques')
plt.suptitle('Distribution des variables numériques')
plt.show()

# %% [markdown]
# * Répartition du nombre d'enfants :

# %%
data_frame['children'].value_counts().plot.bar(title="Répartition du nombre d'enfants")
# Out:
# <Axes: title={'center': "Répartition du nombre d'enfants"}, xlabel='children'>

# %% [markdown]
# * Charges par rapport à l'âge (fumeur / non fumeur):

# %%
sbs.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sbs.scatterplot(data=data_frame, x="age", y="charges", hue="smoker", alpha=0.6)
plt.title("Distribution des charges par rapport à l'âge (fumeur/non fumeur)")
plt.xlabel("Âge")
plt.ylabel("Charges")
plt.show()

# %% [markdown]
# * Charges par rapport à l'âge (sex) :

# %%
sbs.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sbs.scatterplot(data=data_frame, x="age", y="charges", hue="sex", alpha=0.6)
plt.title("Distribution des charges par rapport à l'âge (homme/femme)")
plt.xlabel("Âge")
plt.ylabel("Charges")
plt.show()

# %% [markdown]
# * Charges par rapport au BMI (fumeur / non fumeur):

# %%
plt.figure(figsize=(10, 6))
sbs.scatterplot(data=data_frame, x="bmi", y="charges", hue="smoker", alpha=0.6)
plt.title("Distribution des charges par rapport au BMI (fumeur/non fumeur)")
plt.xlabel("BMI")
plt.ylabel("Charges")
plt.show()

# %% [markdown]
# * Charges par rapport au BMI (homme/femme):

# %%
plt.figure(figsize=(10, 6))
sbs.scatterplot(data=data_frame, x="bmi", y="charges", hue="sex", alpha=0.6)
plt.title("Distribution des charges par rapport au BMI (homme/femme)")
plt.xlabel("BMI")
plt.ylabel("Charges")
plt.show()

# %% [markdown]
# * Répartition Fumeurs vs Non-fumeurs && Répartition par région

# %%
data = data_frame['smoker'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(data.values, labels=data.index, autopct='%1.1f%%', startangle=45, colors=['lightblue', 'lightcoral'])
plt.title('Répartition Fumeurs vs Non-fumeurs')
plt.axis('equal') 
plt.show()

data = data_frame['region'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(data.values, labels=data.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral', '#aaaaaa', '#00FFAA'])
plt.title('Répartition par région')
plt.axis('equal') 
plt.show()

# %% [markdown]
# * Pairplot des variables numériques selon le statut fumeur :

# %%
pairplot_fig = sbs.pairplot(data_frame, hue='smoker', height=2.5)
pairplot_fig.fig.suptitle("Pairplot des variables numériques selon le statut fumeur", y=1.02)
# Out:
# Text(0.5, 1.02, 'Pairplot des variables numériques selon le statut fumeur')

# %% [markdown]
# * Distribution de l'indice de masse corporelle (BMI):

# %%
sbs.distplot(data_frame['bmi'], kde=True)
plt.title("Distribution de l'indice de masse corporelle (BMI)")
plt.xlabel("BMI")
plt.ylabel("Densité")
plt.show()
# Out:
# C:\Users\ramas\AppData\Local\Temp\ipykernel_7844\4084341246.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbs.distplot(data_frame['bmi'], kde=True)

# %% [markdown]
# * Distribution de charges :

# %%
sbs.distplot(data_frame['charges'], kde=True)
plt.title("Distribution de charges")
plt.xlabel("Charges")
plt.ylabel("Densité")
plt.show()
# Out:
# C:\Users\ramas\AppData\Local\Temp\ipykernel_7844\577396260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbs.distplot(data_frame['charges'], kde=True)

# %% [markdown]
# * matrices de corrélation et de visualisations :

# %%
# pour les variables numériques : 
numeric_df = data_frame.select_dtypes(include=[np.number])
print(numeric_df.head())

plt.figure(figsize=(8, 6))
sbs.heatmap(numeric_df.corr(), annot=True, cmap="viridis", fmt=".2f")
plt.title("matrices de corrélation des variables numériques : ")
# Out:
#    age     bmi  children      charges
# 0   19  27.900         0  16884.92400
# 1   18  33.770         1   1725.55230
# 2   28  33.000         3   4449.46200
# 3   33  22.705         0  21984.47061
# 4   32  28.880         0   3866.85520
# Text(0.5, 1.0, 'matrices de corrélation des variables numériques : ')

# %%
# pour les colonnes catégorielles et numériques : 

encoded_df = pd.get_dummies(data_frame, drop_first=True)
# print(encoded_df)

plt.figure(figsize=(10, 8))
sbs.heatmap(encoded_df.corr(), annot=True, cmap="RdBu_r", fmt=".2f")
plt.title("Matrice de corrélation (numériques + catégorielles encodées)")
plt.show()
